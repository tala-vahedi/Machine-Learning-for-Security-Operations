# %% [markdown]
# <!-- Tala Vahedi
# October 30, 2021
# Week Ten Assignment
#
# Script Purpose: Perform the Scikit-Learn Tutorial
# Script Version: 1.0
# Script Author:  Tala Vahedi, University of Arizona
#
# Script Revision History:
# Version 1.0 Oct 30, 2021, Python 3.x
#
# Using the Scikit-Learn Tutorial found here:  https://www.dataquest.io/blog/sci-kit-learn-tutorial/
# Perform the operations from the beginning of the Tutorial stopping when you get to the Building the
# Model Section.
#
# Create a Report that captures each major steps of the process and provide a short write up of what
# you learned during that step and what areas are you still confused about.
#  -->

# %%
# Psuedo Constants
SCRIPT_NAME    = "Script: Perform Sentiment Analysis using K-Nearest Neighbor Classification model "
SCRIPT_VERSION = "Version 1.0"
SCRIPT_AUTHOR  = "Author: Tala Vahedi"

# Python Standard Library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Print Basic Script Information
print()
print(SCRIPT_NAME)
print(SCRIPT_VERSION)
print(SCRIPT_AUTHOR)
print()
# Out:
# Script: Perform Sentiment Analysis using K-Nearest Neighbor Classification model
# Version 1.0
# Author: Tala Vahedi

# %%
# Read in the data with `read_csv()`
data = pd.read_csv("nuclearPower.csv", dtype=str)

# Using .head() method to view the first few records of the data set
data.head()
# Out:
#                                           tweet_text  \
# 0  :Hello Japan is a nuclear power plant crisis. ...
# 1  . Renewable Energy Consumption Tops Nuclear fo...
# 2  . Will liberals now seek to eliminate dangerou...
# 3  (Aug 22,2011)Plant Status of Fukushima Daiichi...
# 4  [ebook] Nuclear Energy and the Environment: Ox...
#
#                                       sentiment  \
# 0                                      Negative
# 1  Neutral / author is just sharing information
# 2  Neutral / author is just sharing information
# 3  Neutral / author is just sharing information
# 4  Neutral / author is just sharing information
#
#                         sentiment_confidence_summary
# 0  "Neutral / author is just sharing information"...
# 1  "Neutral / author is just sharing information"...
# 2  "Neutral / author is just sharing information"...
# 3  "Neutral / author is just sharing information"...
# 4  "Neutral / author is just sharing information"...

# %%
# using the dtypes() method to display the different datatypes available
data.dtypes
# Out:
# tweet_text                      object
# sentiment                       object
# sentiment_confidence_summary    object
# dtype: object

# %%
# preprocess data: make lower case
data = data.apply(lambda x: x.astype(str).str.lower())

data.head()
# Out:
#                                           tweet_text  \
# 0  :hello japan is a nuclear power plant crisis. ...
# 1  . renewable energy consumption tops nuclear fo...
# 2  . will liberals now seek to eliminate dangerou...
# 3  (aug 22,2011)plant status of fukushima daiichi...
# 4  [ebook] nuclear energy and the environment: ox...
#
#                                       sentiment  \
# 0                                      negative
# 1  neutral / author is just sharing information
# 2  neutral / author is just sharing information
# 3  neutral / author is just sharing information
# 4  neutral / author is just sharing information
#
#                         sentiment_confidence_summary
# 0  "neutral / author is just sharing information"...
# 1  "neutral / author is just sharing information"...
# 2  "neutral / author is just sharing information"...
# 3  "neutral / author is just sharing information"...
# 4  "neutral / author is just sharing information"...

# %%
# preprocess data: remove non ascii characters
data.tweet_text.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
data.sentiment.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
data.sentiment_confidence_summary.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)

data.head()
# Out:
#                                           tweet_text  \
# 0  :hello japan is a nuclear power plant crisis. ...
# 1  . renewable energy consumption tops nuclear fo...
# 2  . will liberals now seek to eliminate dangerou...
# 3  (aug 22,2011)plant status of fukushima daiichi...
# 4  [ebook] nuclear energy and the environment: ox...
#
#                                       sentiment  \
# 0                                      negative
# 1  neutral / author is just sharing information
# 2  neutral / author is just sharing information
# 3  neutral / author is just sharing information
# 4  neutral / author is just sharing information
#
#                         sentiment_confidence_summary
# 0  "neutral / author is just sharing information"...
# 1  "neutral / author is just sharing information"...
# 2  "neutral / author is just sharing information"...
# 3  "neutral / author is just sharing information"...
# 4  "neutral / author is just sharing information"...

# %%
# converting dtype to string 
data["tweet_text"]= data["tweet_text"].astype(str) 
data["sentiment"]= data["sentiment"].astype(str) 
data["sentiment_confidence_summary"]= data["sentiment_confidence_summary"].astype(str) 

# removing special characters in all columns 
data["tweet_text"]= data['tweet_text'].map(lambda x: re.sub(r'\W+', ' ', x))
data["sentiment"]= data['sentiment'].map(lambda x: re.sub(r'\W+', ' ', x))
data["sentiment_confidence_summary"]= data['sentiment_confidence_summary'].map(lambda x: re.sub(r'\W+', ' ', x))

data.head()
# Out:
#                                           tweet_text  \
# 0   hello japan is a nuclear power plant crisis l...
# 1   renewable energy consumption tops nuclear for...
# 2   will liberals now seek to eliminate dangerous...
# 3   aug 22 2011 plant status of fukushima daiichi...
# 4   ebook nuclear energy and the environment oxf ...
#
#                                     sentiment  \
# 0                                    negative
# 1  neutral author is just sharing information
# 2  neutral author is just sharing information
# 3  neutral author is just sharing information
# 4  neutral author is just sharing information
#
#                         sentiment_confidence_summary
# 0   neutral author is just sharing information 0 ...
# 1    neutral author is just sharing information 1 0
# 2   neutral author is just sharing information 0 ...
# 3    neutral author is just sharing information 1 0
# 4    neutral author is just sharing information 1 0

# %%
# preprocess data: remove stop words
with open("STOP_WORDS.txt", 'r') as stopWordList:
    stopWords = stopWordList.read()
STOP_WORDS = stopWords.split()

data['tweet_text'] = data['tweet_text'].apply(lambda x: ' '.join([item for item in x.split() if item not in STOP_WORDS]))
data['sentiment'] = data['sentiment'].apply(lambda x: ' '.join([item for item in x.split() if item not in STOP_WORDS]))
data['sentiment_confidence_summary'] = data['sentiment_confidence_summary'].apply(lambda x: ' '.join([item for item in x.split() if item not in STOP_WORDS]))

data.head()
# Out:
#                                           tweet_text               sentiment  \
# 0        hello japan nuclear power plant crisis link                negative
# 1  renewable energy consumption tops nuclear firs...  neutral author sharing
# 2  liberals now seek eliminate dangerous nuclear ...  neutral author sharing
# 3  aug 22 2011 plant status fukushima daiichi nuc...  neutral author sharing
# 4  ebook nuclear energy environment oxf ord un iv...  neutral author sharing
#
#                   sentiment_confidence_summary
# 0      neutral author sharing 0 2 negative 0 8
# 1                   neutral author sharing 1 0
# 2  neutral author sharing 0 667 negative 0 333
# 3                   neutral author sharing 1 0
# 4                   neutral author sharing 1 0

# %%
# splitting the sentiment target variable into only negative, neutral and positive tags
data['sentiment'] = data['sentiment'].str.split(' ').str[0]
# removing the weak confidence scores for the sentiments
data['sentiment_confidence_summary'] = data['sentiment_confidence_summary'].str.split(' ').str[0]

# filtering out rows that dont have negative confidence into a new dataframe
dataPreprocessed = data[data['sentiment_confidence_summary'] != "negative"]
# dropping the sentiment confidence column since it is no longer needed
dataPreprocessed = dataPreprocessed.drop(columns=['sentiment_confidence_summary'])
dataPreprocessed.head()
# Out:
#                                           tweet_text sentiment
# 0        hello japan nuclear power plant crisis link  negative
# 1  renewable energy consumption tops nuclear firs...   neutral
# 2  liberals now seek eliminate dangerous nuclear ...   neutral
# 3  aug 22 2011 plant status fukushima daiichi nuc...   neutral
# 4  ebook nuclear energy environment oxf ord un iv...   neutral

# %%
# convert the sales data features that have string values into numeric labels
print("tweet : ", dataPreprocessed['tweet_text'].unique())
print("sentiment : ", dataPreprocessed['sentiment'].unique())
# Out:
# tweet :  ['hello japan nuclear power plant crisis link'
#  'renewable energy consumption tops nuclear firsttime link nuclear energy renewable'
#  'liberals now seek eliminate dangerous nuclear power plants link green energy news'
#  'aug 22 2011 plant status fukushima daiichi nuclear power station 3 00 pm aug 22 link tepco japan'
#  'ebook nuclear energy environment oxf ord un iversity pr ess 2011 isbn 0841225850 432 p link'
#  'gjobs nuclear power safety campaign organizer temporary union concerned scientists cambridge ma link'
#  'news nuclear power plant radioactive tritium contamination vermont link nwo'
#  'science nuclear energy environment oxf ord un iversity pr ess 2011 isbn 0841225850 432 link'
#  'link p windmills produce power one average nuclear power station windmills'
#  'link quot thing quot m nuclear energy correctly plant built 1970 s standard'
#  'link 6 min video masao yoshida fukushima diichi nuclear station all aid reports current progress'
#  'link 74 percent favor gradual reduction nuclear power plants mainichi poll mainichi daily news'
#  'link coal alternative nuclear power egat'
#  'link experts economic side project lithuanian nuclear power plant'
#  'link star_ enters nuclear power supply market'
#  'link star_ enters nuclear power supply market pr newswire press release'
#  'link health newspaper articles complete rejection peaceful nuclear energy require multi dollar inves'
#  'link india accord highest safety standards civil nuclear energy pm economic times'
#  'link nuclear power 101 via arnie gundersen w resume mention sccouncil nirs'
#  'link pm bats nuclear energy times india'
#  'link saudi arabia s nuclear energy ambitions energy collective'
#  'link 1940 olympics decreased rice consumption improved health nuclear power per link'
#  'link s happening mention fukushima nuclear power plant'
#  'link dozen wind turbines nuclear power plant turbines power'
#  'link ynn marist poll new yorkers feel nuclear power hydrofracking'
#  'mention hears talk place north mi nuclear power plant bow hunting'
#  'mention s north west missouri s wma nuclear power plant 6000 ac buddy go bow'
#  'mention lol best bumper sticker saw quot nuclear power safer ted kennedy s car quot guess one dates'
#  'mention newamerica9 com investment website talking nuclear energy dangers'
#  'rt mention science saturday nuclear energy melting ice caps human adaptation link'
#  'rt mention hinkley point c britain s newest nuclear power station nuclear'
#  'mention mention mess am thinking moving way 2012 link'
#  'rt mention mention mention corino bigger threat death limerick nuclear power plant surviving abortion'
#  'mention mention corino bigger threat death limerick nuclear power plant surviving abortion'
#  'rt mention mention quot open mind quot nuclear energy concerned nuclear waste water plant cagov nuclear'
#  'rt mention mention nuclear power plant all now shout everyday rt heart'
#  'mention mention nuclear energy good worth risk radiation extreme levels'
#  'mention mention problem prosperity built nuclear energy renewables trouble now'
#  'rt mention mention top 10 things indian citizens case nuclear power plant accident country link'
#  'rt mention mention gotta pioneer new technologies help us all endure radiation shut nuclear energy plants good tesla'
#  'rt mention 31119 23798 31532 19968 21407 30330 12289 22320 38754 12364 12402 12403 21106 12428 12289 25918 23556 33021 29289 36074 12434 21547 12416 33976 27671 12364 19978 12364 12387 12390 12356 12427 12290 65288 russia today 65289 rt ground cracking underneath fukushima nuclear link fukushima'
#  'mention gt good decision evidence nuclear power smartgrid can t survive corporateentitlement'
#  'rt mention inharperstopsyturvycanada nuclear power considered safe affordable green power cdnpoli'
#  'rt mention marxism socialism nuclear power plant workers defeat attack pensions 18 day strike link p2 rebelleft'
#  'rt mention news energy nuclear power generation touch 20 000 mw 20 years link'
#  'rt mention news industrynews nuclear power generation touch 20 000 mw 20 years link'
#  'rt mention nuclear turkey moves forward nuclear energy plans marketplace publicradio org link'
#  'rt mention smr nuclear technology __it s impede development link nuclear energy'
#  'rt mention tepco desalinate fuel pools fukushima daiichi nuclear energy facility link'
#  'rt mention utah moving closer nuclear power plant link'
#  'rt mention vermont yankee nuclear power plant vermont groups team fight nuclear relicensing link'
#  'rt mention 15 years french nuclear energy use created waste room dedicated storage link'
#  'mention 4 30 pm et watch nuclear energy town hall meeting august 2 florida channel amp web1 thefloridachannel org'
#  'rt mention 5 largest solar installations promising alternatives nuclear power plants link'
#  'rt mention 66th carnival nuclear energy bloggers online now ans nuclear cafe link'
#  'mention years ago told sufficient nuclear power 1x1m cubes cld power town 15 years called'
#  'rt mention photographer exclusive pictures inside fukushima nuclear power plant link'
#  'rt mention planet powered thorium thorium reactors rescue nuclear power link'
#  'rt mention abbasi russia proposed cooperating iran building new nuclear power plants country link via mention'
#  'rt mention activists guide fighting nuclear power public citizen climate energy link via mention'
#  'rt mention transcanada tar sands expose 7 pipelines nuclear power fit strategy link'
#  'rt mention alabama nuclear power plant go ahead construction link rt s'
#  'rt mention interview mention nuclear power safe learned japan link'
#  'rt mention ans nuclear cafe saudi arabia boosts nuclear energy ambitions link'
#  'rt mention anti nuclear power t shirt link nonukes'
#  'rt mention buy floating nuclear power plant cheap link via mention'
#  'mention guys going phasing nuclear energy'
#  'rt mention china pushes forward nuclear energy u s held red tape irrational fear link'
#  'rt mention best new alabama nuclear power plant meltdown wind carry all radiation knoxville'
#  'rt mention blue castle nuclear project closer filing licensing application link nuclear energy electricity utilities'
#  'mention breaking hokkaido governor formally approves restart commercial operations 3 reactor tomari nuclear power plant'
#  'rt mention can tokyo function nuclear power asks mention link'
#  'rt mention canada may nation use nuclear energy accelerate fossil fuel production cfsfcee'
#  'rt mention china takes lead race clean nuclear power thorium link'
#  'mention climate change real nuclear power safe facts denied alternate groups ultimate frustration'
#  'rt mention coal alternative nuclear power egat link'
#  'mention couple nuclear power 100 efficient electric motors wasteless process carbon emission'
#  'mention cucumbers nuclear power' 'rt mention debate nuclear energy link'
#  'rt mention devastating march 11 earthquake leaves japan pondering fuel mix platts barrel blog link nuclear energy'
#  'mention mention ancient aliens all way earth mine gold nuclear power gold exists earth'
#  'rt mention discussion nuclear energy safer link'
#  'rt mention facts us nuclear energy production get updated quot cheat sheet quot quick facts link'
#  'rt mention informed update clean progress fukushima nuclear power plant disappeared news'
#  'rt mention don t count nuclear energy yet summer meeting american nuclear society wa link'
#  'rt mention exelon ceo ans nation dispense fukushima fears nuclear energy link'
#  'rt mention expert commentary safety nuclear energy link'
#  'mention fission theory s all nuclear power plants 93 miles earth work'
#  'rt mention floating nuclear power plant seized court bit ly qyrdxw via mention'
#  'rt mention florida senator challenges utilities nuclear power cost recovery link sayfie mention mention'
#  'rt mention florida persevere nuclear power plants great op ed article editors d link nuclear energy'
#  'rt mention seeking info gt soundbites rt mention ve updated nei myths amp facts nuclear energy link'
#  'rt mention wsmv tva nuke construction rates board agenda nuclear power plant safety fossil fuel emissions ar link'
#  'rt mention fukushima dai ichi nuclear power plant may achieve cold shutdown planned tokyo cont link'
#  'mention ge laser breakthrough lead lower cost nuclear energy reduced fossil fuel sales motive opposition'
#  'rt mention germany plans move nuclear power constitutes 22 country_s energy source 11 years via mention'
#  'mention got hacked anonymous anonymous hacked fbi russian nuclear power plant'
#  'rt mention govt expanding civil nuclear energy programme pm link'
#  'mention happy spread word fine nuclear power plant'
#  'mention quot open mind nuclear energy quot tells fresbee edit board cites climate change major reason 4 stance 559vote'
#  'mention quot open mind quot nuclear energy concerned nuclear waste water plant cagov nuclear'
#  'mention follow advices recognize mistakes nuclear energy link link'
#  'rt mention hillsborough students attend nuclear energy forum hillsborough teens 200 new jersey high school stu link'
#  'mention hmmm read views environmental nuclear energy policies'
#  'rt mention kids schooled nuclear industry link via mention'
#  'rt mention am tweeting quot nuclear power plant quot quot re tweet quot tweet no_nukes genpatsu 21407 30330 12392 12417 12429 s_t_r'
#  'mention nuclear power plant all now shout everyday rt heart'
#  'mention d go mlp universe introduce nuclear energy warfare strategies ponies fuckthepolice'
#  'rt mention m confused japan s nuclear energy threat iran s physics work all'
#  'mention m assuming nuclear power growing industry now'
#  'mention m skeptical shit nuclear energy apart quot public scared shitless quot'
#  'rt mention idaho samizdat nuke notes 66th carnival nuclear energy bloggers link'
#  'mention mcguinty way natural gas redundant expensive wind solar dangerous nuclear energy replace'
#  'rt mention work can phase nuclear power replace clean energy'
#  'rt mention national science politics news pm nuclear energy vital growth'
#  'rt mention japan 6th graders field trips nuclear power plants gees field trips movie theater boring'
#  'rt mention india nuclear power generation touch 20 000 mw country s nuclear power generation link'
#  'rt mention india accord highest safety standards civil nuclear energy pm link'
#  'rt mention internet weather forecasting gps commercial aviation freight nuclear energy things common'
#  'rt mention iran s top diplomat discuss nuclear energy issues moscow ali akbar salehi foreign minister iran link'
#  'rt mention saudiarabia making transition oil nuclear link gt sa bearish oil all notice'
#  'rt mention issues nuclear energy amp waste fact sheet link lt reprocessing nuclear waste creates nuclear waste'
#  'mention politically speaking us s way jumping nuclear power japan incident happened'
#  'rt mention s sad society scared use technology nuclear power progress_ cont link'
#  'mention lol years working nuclear power plant'
#  'rt mention mark hibbs saudi arabia_s nuclear energy ambitions link'
#  'rt mention good news russia proposes construct nuclear plants iran link'
#  'rt mention nuclear power link'
#  'rt mention potential energy nuclear power plant cannabis safer healing properties alcohol cannabis safer themarijuanateaparty org'
#  'mention mr vat quot oh mr burns insightful sitting office nuclear power plant tear schools quot'
#  'mention quot agenda quot spreading calm certainty reassurance aka truth nuclear energy response fud'
#  'mention work s crazy m going get nice quiet job nuclear power plant'
#  'mention nah man thing nuclear power supporters nimbyism support long doesn t relate'
#  'rt mention nation hit bombs big bet nuclear power link'
#  'rt mention new nuclear power plants expensive build exelon s ceo link'
#  'rt mention ngos academics call abolition nuclear plants antinuclear nongovernmental organizations academics ca link'
#  'rt mention nukes logo link via mention'
#  'rt mention japan nuclear power plant all lot problems save children link'
#  'rt mention now earthquake tsunami damage reported nuclear power plants japan'
#  'rt mention nuclear blog digest rt mention 65th carnival nuclear energy bloggers link nuclear'
#  'rt mention nuclear energy declines greener energy emerges re arizona re talkin link'
#  'rt mention nuclear energy hell way boil water quot albert einstein 12300 21407 23376 21147 12399 28271 12434 27832 12363 12377 26041 27861 12398 22320 29508 12391 12377 12301 12450 12523 12496 12540 12488 12539 12450 12452 12531 12471 12517 12479 12452 12531 exite 32763 35379 12290 22320 29508 12384 12424 65281 12504 12523 65281 22320 29508 12398 28271 27832 12363 12375 22120 65281 12450 12507 65281'
#  'rt mention nuclear energy expensive dangerous way boil water s screws earth uninhabitable humans'
#  'rt mention nuclear energy capitalism communism international link'
#  'rt mention nuclear power fukushima energy future reprint article fm jun 20 national review link'
#  'mention nuclear power best interest future saskatchewan leader uranium backwards hypocrite'
#  'rt mention nuclear power plant construction spending approved vogtle site ga link mention'
#  'mention nuclear power zealous protectionism arms ironically horses frogs snails sparrows otters voles topless birds'
#  'rt mention ny times german chancellor merkel white washes abrupt politically expedient u turn nuclear energy link'
#  'mention new green energy nuclear energy 21st century'
#  'rt mention progress report fukushima daiichi link nuclear energy'
#  'rt mention protect nuclear power plant radiation plan evacuation route safe zones link'
#  'rt mention public support nuclear energy remains strong link'
#  'rt mention quote day florida afford consequences including nuclear power link nuclear energy'
#  'rt mention radioactive leak fort calhoun nuclear power station nuclear radioactive leak fort calhoun nuclear p link'
#  'rt mention random garmentcare fact hepa filters designed nuclear power plants'
#  'rt mention reading china_s nuclear power plans unfazed fukushima disaster mention link link'
#  'rt mention remember two three american nuclear power plants water leaking news coverage blackout corruptmedia'
#  'mention report laser advances nuclear fuel stir terror fear quot proves can t divorce nuclear energy nonproliferation discussions'
#  'rt mention reporting grounds fukushima daiichi nuclear power station link'
#  'mention rolling regulations trust wallstreet oil nuclear energy corps thing'
#  'rt mention rt mention 66th carnival nuclear energy bloggers online now ans nuclear cafe link'
#  'rt mention rt mention progress report fukushima daiichi link nuclear energy'
#  'rt mention rt_ mention report ground fukushima plant cracking amp venting radioactive steam link quot abandon nuclear power altogether quot'
#  'rt mention russia talks build nuclear power plants iran magog persia naturally'
#  'rt mention russia proposed cooperating w ir building new nuclear power plants iran s nuclear chief presstv link'
#  'rt mention saudi arabia boosts nuclear energy ambitions link nuclear lt disturbs women can t drive'
#  'rt mention saudi arabia_s nuclear energy ambitions filed energy news link'
#  'rt mention science saturday nuclear energy melting ice caps human adaptation bloggingheads tv science satu link'
#  'rt mention nuclear power feared understood link fukushima energy germany japan orcot'
#  'rt mention slovenia s nuclear power plant krsko mention news link'
#  'rt mention smart post rt mention studying radioactive sulfur fukushima isn t nuclear power s coal bit ly r2kcai'
#  'mention sounds good agreed boats larger keepout zone time due nuclear power source'
#  'rt mention spotlight u s nuclear safety nuclear safety multiple strengthening grids integral link nuclear energy'
#  'mention people died due nuclear power us'
#  'rt mention talking start building nuclear power plants oil drilling get patriot charge verbal muslim lib diarrhea far'
#  'rt mention studying radioactive sulfur fukushima isn t nuclear power s coal link'
#  'mention tainted food bribery issues nuclear power s saw japan s future quake future book'
#  'mention nice quot health safety conciderations fukushima nuclear power plant workers risk heat realted illness quot'
#  'rt mention 65th carnival pro nuclear blogs podcasts nei nuclear notes find nukes link'
#  'rt mention cement engulfed organs muscles skin heart heart forged nuclear power man stone'
#  'mention drinking bird predisposed venting gas springfield nuclear power plant'
#  'rt mention nuclear reactor fukushima s accident reactivated reactivation featuring firs link'
#  'rt mention government plans rent all land owned residents parts entry zone fukushima nuclear power plant link'
#  'rt mention hindu news national nuclear energy play role manmohan link link'
#  'rt mention nuclear energy option famous book prof l b cohen free link'
#  'rt mention us nuclear industry 7 steps reconfirm safety amp emergency preparedness nuclear plants learn link']
# sentiment :  ['negative' 'neutral' 'positive' 'tweet']

# %%
#import the necessary module
from sklearn import preprocessing
# create the Labelencoder object
le = preprocessing.LabelEncoder()
#convert the categorical columns into numeric
dataPreprocessed['tweet_text'] = le.fit_transform(dataPreprocessed['tweet_text'])
dataPreprocessed['sentiment'] = le.fit_transform(dataPreprocessed['sentiment'])
#display the initial records
dataPreprocessed.head()
# Out:
#    tweet_text  sentiment
# 0           3          0
# 1          69          1
# 2           4          1
# 3           0          1
# 4           1          1

# %%
#assigning the target variable
target = dataPreprocessed['sentiment']
dataPreprocessed.head(10)
# Out:
#    tweet_text  sentiment
# 0           3          0
# 1          69          1
# 2           4          1
# 3           0          1
# 4           1          1
# 5           2          1
# 6          68          1
# 7         186          1
# 8          14          1
# 9          16          2

# %%
#import the necessary module
from sklearn.model_selection import train_test_split
#split data set into train and test sets
data_train, data_test, target_train, target_test = train_test_split(dataPreprocessed,target, test_size = 0.30, random_state = 10)

# %%
#import necessary modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
#create object of the lassifier
neigh = KNeighborsClassifier(n_neighbors=3)
#Train the algorithm
neigh.fit(data_train, target_train)
# predict the response
pred = neigh.predict(data_test)
# evaluate accuracy
print ("KNeighbors accuracy score : ",accuracy_score(target_test, pred))
# Out:
# KNeighbors accuracy score :  0.8596491228070176
